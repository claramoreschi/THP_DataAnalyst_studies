# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv("/Users/claramoreschi/Desktop/data/cwurData.csv", encoding='latin-1')
data2 = pd.read_csv("/Users/claramoreschi/Desktop/data/educational_attainment_supplementary_data.csv", encoding='latin-1')
data3 = pd.read_csv("/Users/claramoreschi/Desktop/data/school_and_country_table.csv", encoding='latin-1')
data4 = pd.read_csv("/Users/claramoreschi/Desktop/data/shanghaiData.csv", encoding='latin-1')
data5 = pd.read_csv("/Users/claramoreschi/Desktop/data/timesData.csv", encoding='latin-1')
data6 = pd.read_csv("/Users/claramoreschi/Desktop/data/expenditure.csv", encoding='latin-1', engine="python")

df1= pd.DataFrame(data1)
df2= pd.DataFrame(data2)
df3= pd.DataFrame(data3)
df4= pd.DataFrame(data4)
df5= pd.DataFrame(data5)
df6= pd.DataFrame(data6)

# %% [markdown]
# ## Classement des meilleures universités du monde

# %%
data1
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998           Federal University of CearÃ¡          Brazil
# 2198         999                University of A CoruÃ±a           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %% [markdown]
# ### Les années prises en charge

# %%
print("Les années prises en charge dans ce classement sont :")
print(" ")
df1['year'].value_counts()
# Out:
# Les années prises en charge dans ce classement sont :
# 2014    1000
# 2015    1000
# 2012     100
# 2013     100
# Name: year, dtype: int64

# %% [markdown]
# ### Ranking obtenu par l'Université de Strasbourg

# %%
rank = df1[df1["institution"].str.contains('Strasbourg')]
print("Les rangs internationaux sont 176 en 2014 et 182 en 2015 ")
print(" ")
print("Les rangs nationaux sont 7 en 2014 et 7 en 2015")

rank
# Out:
# Les rangs internationaux sont 176 en 2014 et 182 en 2015
#
# Les rangs nationaux sont 7 en 2014 et 7 en 2015
#       world_rank               institution country  national_rank  \
# 375          176  University of Strasbourg  France              7
# 1381         182  University of Strasbourg  France              7
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 375                     59                478                  55
# 1381                    71                567                  49
#
#       publications  influence  citations  broad_impact  patents  score  year
# 375            190        135        250         224.0      204  48.61  2014
# 1381           191        145        264         219.0      269  47.89  2015

# %% [markdown]
# ## Les niveaux de scolarité supplémentaires

# %%
data2
# Out:
#                                             country_name  \
# 0                                            Afghanistan
# 1                                            Afghanistan
# 2                                            Afghanistan
# 3                                            Afghanistan
# 4                                            Afghanistan
# ...                                                  ...
# 79050                                                NaN
# 79051                                                NaN
# 79052                                                NaN
# 79053  Data from database: Education Statistics: Educ...
# 79054                           Last Updated: 10/20/2015
#
#                                              series_name  1985  1986  1987  \
# 0      Barro-Lee: Average years of primary schooling,...  0.33   NaN   NaN
# 1      Barro-Lee: Average years of primary schooling,...  1.03   NaN   NaN
# ...

# %% [markdown]
# ### Les années prises en charge

# %%
print("Les années prises en charge dans ce classement sont :")
print (" ")
df2.columns[2:]
# Out:
# Les années prises en charge dans ce classement sont :
# Index(['1985', '1986', '1987', '1990', '1991', '1992', '1993', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2015'],
#       dtype='object')

# %% [markdown]
# ## Listes des meilleures universités du monde et leur pays

# %%
data3
# Out:
#                                school_name                   country
# 0                       Harvard University  United States of America
# 1       California Institute of Technology  United States of America
# 2    Massachusetts Institute of Technology  United States of America
# 3                      Stanford University  United States of America
# 4                     Princeton University  United States of America
# ..                                     ...                       ...
# 813                      Xidian University                     China
# 814                    Yeungnam University               South Korea
# 815          YÄ±ldÄ±z Technical University                    Turkey
# 816               Yokohama City University                     Japan
# 817           Yokohama National University                     Japan
#
# [818 rows x 2 columns]

# %% [markdown]
# ### Ranking obtenus par l'université de Strasbourg

# %%
print("Le rang obtenu par Strasbourg est 242")

rank = df3[df3["school_name"].str.contains('Strasbourg')]
rank
# Out:
# Le rang obtenu par Strasbourg est 242
#                   school_name country
# 242  University of Strasbourg  France

# %% [markdown]
# ## Rangs des meilleurs étudiants de Shanghai (?)

# %%
data4
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 2             3                          Stanford University             2
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# ...         ...                                          ...           ...
# 4892    401-500                        University of Trieste         11-20
# 4893    401-500                       University of Zaragoza          9-13
# 4894    401-500                        Utah State University       126-146
# 4895    401-500              Vienna University of Technology           4-6
# 4896    401-500                       Wake Forest University       126-146
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# ...

# %% [markdown]
# ### Les années prises en charge

# %%
print("Les années prises en charge dans ce classement sont :")
print(" ")
df4['year'].value_counts()
# Out:
# Les années prises en charge dans ce classement sont :
# 2007    510
# 2008    503
# 2009    501
# 2005    500
# 2006    500
# 2010    500
# 2011    500
# 2014    500
# 2015    500
# 2012    284
# 2013     99
# Name: year, dtype: int64

# %% [markdown]
# ## J'ai pas trop compris à quoi servait ce tableau

# %%
data5
# Out:
#      world_rank                        university_name  \
# 0             1                     Harvard University
# 1             2     California Institute of Technology
# 2             3  Massachusetts Institute of Technology
# 3             4                    Stanford University
# 4             5                   Princeton University
# ...         ...                                    ...
# 2598    601-800                    Yeungnam University
# 2599    601-800          YÄ±ldÄ±z Technical University
# 2600    601-800               Yokohama City University
# 2601    601-800           Yokohama National University
# 2602    601-800                     Yuan Ze University
#
#                        country  teaching international  research  citations  \
# 0     United States of America      99.7          72.4      98.7       98.8
# 1     United States of America      97.7          54.6      98.0       99.9
# ...

# %% [markdown]
# ### Les années prises en charge

# %%
print("Les années prises en charge dans ce classement sont :")
print(" ")
df5['year'].value_counts()
# Out:
# Les années prises en charge dans ce classement sont :
# 2016    800
# 2012    402
# 2015    401
# 2013    400
# 2014    400
# 2011    200
# Name: year, dtype: int64

# %% [markdown]
# ## Dépenses dans l'éducation

# %%
data6
# Out:
#                   country                  institute_type  \
# 0            OECD Average               All Institutions
# 1               Australia               All Institutions
# 2                 Austria               All Institutions
# 3                 Belgium               All Institutions
# 4                  Canada               All Institutions
# ..                    ...                             ...
# 328                Turkey  Higher Education Institutions
# 329        United Kingdom  Higher Education Institutions
# 330         United States  Higher Education Institutions
# 331                Brazil  Higher Education Institutions
# 332    Russian Federation  Higher Education Institutions
#
#     direct_expenditure_type  1995  2000  2005  2009  2010  2011
# 0                    Public   4.9   4.9   5.0   5.4   5.4   5.3
# 1                    Public   4.5   4.6   4.3   4.5   4.6   4.3
# 2                    Public   5.3   5.4   5.2   5.7   5.6   5.5
# ...

# %% [markdown]
# ### Les années prises en charge

# %%
print("Les années prises en charge dans ce classement sont :")
print (" ")
df6.columns[2:]
# Out:
# Les années prises en charge dans ce classement sont :
# Index(['direct_expenditure_type', '1995', '2000', '2005', '2009', '2010',
#        '2011'],
#       dtype='object')
